# %%
import pandas as pd

import numpy as np
data=pd.read_csv(r'C:\Users\Maitexa user\Desktop\nihana\kidney disease\kidney_disease.csv')
data.head()
# Out:
#    id   age    bp     sg   al   su     rbc        pc         pcc          ba  \
# 0   0  48.0  80.0  1.020  1.0  0.0     NaN    normal  notpresent  notpresent
# 1   1   7.0  50.0  1.020  4.0  0.0     NaN    normal  notpresent  notpresent
# 2   2  62.0  80.0  1.010  2.0  3.0  normal    normal  notpresent  notpresent
# 3   3  48.0  70.0  1.005  4.0  0.0  normal  abnormal     present  notpresent
# 4   4  51.0  80.0  1.010  2.0  0.0  normal    normal  notpresent  notpresent
#
#    ...  pcv    wc   rc  htn   dm  cad appet   pe  ane classification
# 0  ...   44  7800  5.2  yes  yes   no  good   no   no            ckd
# 1  ...   38  6000  NaN   no   no   no  good   no   no            ckd
# 2  ...   31  7500  NaN   no  yes   no  poor   no  yes            ckd
# 3  ...   32  6700  3.9  yes   no   no  poor  yes  yes            ckd
# 4  ...   35  7300  4.6   no   no   no  good   no   no            ckd
#
# [5 rows x 26 columns]

# %%
data.drop(['id'],axis=1,inplace=True)

# %%
data.head(3)
# Out:
#     age    bp    sg   al   su     rbc      pc         pcc          ba    bgr  \
# 0  48.0  80.0  1.02  1.0  0.0     NaN  normal  notpresent  notpresent  121.0
# 1   7.0  50.0  1.02  4.0  0.0     NaN  normal  notpresent  notpresent    NaN
# 2  62.0  80.0  1.01  2.0  3.0  normal  normal  notpresent  notpresent  423.0
#
#    ...  pcv    wc   rc  htn   dm cad appet  pe  ane classification
# 0  ...   44  7800  5.2  yes  yes  no  good  no   no            ckd
# 1  ...   38  6000  NaN   no   no  no  good  no   no            ckd
# 2  ...   31  7500  NaN   no  yes  no  poor  no  yes            ckd
#
# [3 rows x 25 columns]

# %%
data['age'].value_counts()
# Out:
# age
# 60.0    19
# 65.0    17
# 48.0    12
# 55.0    12
# 50.0    12
#         ..
# 83.0     1
# 27.0     1
# 14.0     1
# 81.0     1
# 79.0     1
# Name: count, Length: 76, dtype: int64

# %%
data['age']=data['age'].fillna(data['age'].mean()).astype('int')

# %%
data.isnull().sum()
# Out:
# age                 0
# bp                 12
# sg                 47
# al                 46
# su                 49
# rbc               152
# pc                 65
# pcc                 4
# ba                  4
# bgr                44
# bu                 19
# sc                 17
# sod                87
# pot                88
# hemo               52
# pcv                70
# wc                105
# rc                130
# htn                 2
# dm                  2
# cad                 2
# appet               1
# pe                  1
# ane                 1
# classification      0
# dtype: int64

# %%
data['bp']=data['bp'].fillna(data['bp'].max()).astype('int')

data['sg']=data['sg'].fillna(data['sg'].mean())

data['al']=data['al'].fillna(data['al'].mean())

data['su']=data['su'].fillna(data['su'].mean())

# %%
data
# Out:
#      age  bp     sg   al   su     rbc        pc         pcc          ba  \
# 0     48  80  1.020  1.0  0.0     NaN    normal  notpresent  notpresent
# 1      7  50  1.020  4.0  0.0     NaN    normal  notpresent  notpresent
# 2     62  80  1.010  2.0  3.0  normal    normal  notpresent  notpresent
# 3     48  70  1.005  4.0  0.0  normal  abnormal     present  notpresent
# 4     51  80  1.010  2.0  0.0  normal    normal  notpresent  notpresent
# ..   ...  ..    ...  ...  ...     ...       ...         ...         ...
# 395   55  80  1.020  0.0  0.0  normal    normal  notpresent  notpresent
# 396   42  70  1.025  0.0  0.0  normal    normal  notpresent  notpresent
# 397   12  80  1.020  0.0  0.0  normal    normal  notpresent  notpresent
# 398   17  60  1.025  0.0  0.0  normal    normal  notpresent  notpresent
# 399   58  80  1.025  0.0  0.0  normal    normal  notpresent  notpresent
#
#        bgr  ...  pcv    wc   rc  htn   dm cad appet   pe  ane classification
# ...

# %%
data['pcv']
# Out:
# 0      44
# 1      38
# 2      31
# 3      32
# 4      35
#        ..
# 395    47
# 396    54
# 397    49
# 398    51
# 399    53
# Name: pcv, Length: 400, dtype: object

# %%
data['bu']=data['bu'].fillna(data['bu'].median())

data['sc']=data['sc'].fillna(data['sc'].median())

data['hemo']=data['hemo'].fillna(data['hemo'].median())

# %%
data
# Out:
#      age  bp     sg   al   su     rbc        pc         pcc          ba  \
# 0     48  80  1.020  1.0  0.0     NaN    normal  notpresent  notpresent
# 1      7  50  1.020  4.0  0.0     NaN    normal  notpresent  notpresent
# 2     62  80  1.010  2.0  3.0  normal    normal  notpresent  notpresent
# 3     48  70  1.005  4.0  0.0  normal  abnormal     present  notpresent
# 4     51  80  1.010  2.0  0.0  normal    normal  notpresent  notpresent
# ..   ...  ..    ...  ...  ...     ...       ...         ...         ...
# 395   55  80  1.020  0.0  0.0  normal    normal  notpresent  notpresent
# 396   42  70  1.025  0.0  0.0  normal    normal  notpresent  notpresent
# 397   12  80  1.020  0.0  0.0  normal    normal  notpresent  notpresent
# 398   17  60  1.025  0.0  0.0  normal    normal  notpresent  notpresent
# 399   58  80  1.025  0.0  0.0  normal    normal  notpresent  notpresent
#
#        bgr  ...  pcv    wc   rc  htn   dm cad appet   pe  ane classification
# ...

# %%
data.shape
# Out:
# (400, 25)

# %%
data.columns
# Out:
# Index(['age', 'bp', 'sg', 'al', 'su', 'rbc', 'pc', 'pcc', 'ba', 'bgr', 'bu',
#        'sc', 'sod', 'pot', 'hemo', 'pcv', 'wc', 'rc', 'htn', 'dm', 'cad',
#        'appet', 'pe', 'ane', 'classification'],
#       dtype='object')

# %%
data.head()
# Out:
#    age  bp     sg   al   su     rbc        pc         pcc          ba    bgr  \
# 0   48  80  1.020  1.0  0.0     NaN    normal  notpresent  notpresent  121.0
# 1    7  50  1.020  4.0  0.0     NaN    normal  notpresent  notpresent    NaN
# 2   62  80  1.010  2.0  3.0  normal    normal  notpresent  notpresent  423.0
# 3   48  70  1.005  4.0  0.0  normal  abnormal     present  notpresent  117.0
# 4   51  80  1.010  2.0  0.0  normal    normal  notpresent  notpresent  106.0
#
#    ...  pcv    wc   rc  htn   dm cad appet   pe  ane classification
# 0  ...   44  7800  5.2  yes  yes  no  good   no   no            ckd
# 1  ...   38  6000  NaN   no   no  no  good   no   no            ckd
# 2  ...   31  7500  NaN   no  yes  no  poor   no  yes            ckd
# 3  ...   32  6700  3.9  yes   no  no  poor  yes  yes            ckd
# 4  ...   35  7300  4.6   no   no  no  good   no   no            ckd
#
# [5 rows x 25 columns]

# %%
data.tail()
# Out:
#      age  bp     sg   al   su     rbc      pc         pcc          ba    bgr  \
# 395   55  80  1.020  0.0  0.0  normal  normal  notpresent  notpresent  140.0
# 396   42  70  1.025  0.0  0.0  normal  normal  notpresent  notpresent   75.0
# 397   12  80  1.020  0.0  0.0  normal  normal  notpresent  notpresent  100.0
# 398   17  60  1.025  0.0  0.0  normal  normal  notpresent  notpresent  114.0
# 399   58  80  1.025  0.0  0.0  normal  normal  notpresent  notpresent  131.0
#
#      ...  pcv    wc   rc  htn  dm cad appet  pe ane classification
# 395  ...   47  6700  4.9   no  no  no  good  no  no         notckd
# 396  ...   54  7800  6.2   no  no  no  good  no  no         notckd
# 397  ...   49  6600  5.4   no  no  no  good  no  no         notckd
# 398  ...   51  7200  5.9   no  no  no  good  no  no         notckd
# 399  ...   53  6800  6.1   no  no  no  good  no  no         notckd
#
# [5 rows x 25 columns]

# %%
pd.set_option('display.max_columns',None)

# %%
data['pcv']=data['pcv'].replace({'\t?':32})

# %%
data['wc']=data['wc'].replace({'\t?':6700})

# %%
data['wc']
# Out:
# 0      7800
# 1      6000
# 2      7500
# 3      6700
# 4      7300
#        ...
# 395    6700
# 396    7800
# 397    6600
# 398    7200
# 399    6800
# Name: wc, Length: 400, dtype: object

# %%
for i in data['rc']:
    print(i)
# Out:
# 5.2
# nan
# nan
# 3.9
# 4.6
# 4.4
# nan
# 5
# 4.0
# 3.7
# nan
# 3.8
# 3.4
# nan
# 2.6
# 2.8
# nan
# nan
# 4.3
# 3.7
# 3.2
# 3.6
# 3.4
# nan
# 4.6
# 3.7
# 4
# 4.1
# nan
# nan
# nan
# 4
# 4.0
# nan
# nan
# 4.9
# nan
# 2.5
# nan
# 4.2
# 4.1
# nan
# 4.5
# 3.1
# nan
# nan
# 4.7
# nan
# 3.5
# 3.5
# 3.8
# nan
# 3.7
# 4.7
# 4.2
# nan
# 3.4
# nan
# 4.3
# nan
# nan
# nan
# 3.8
# nan
# nan
# nan
# nan
# nan
# nan
# 6.0
# 5.2
# 3.2
# nan
# nan
# 3.4
# nan
# 4
# 3.7
# nan
# 5.0
# 3.8
# 3.7
# nan
# nan
# 2.1
# nan
# nan
# 5
# 4.7
# nan
# 4.2
# 5.6
# 3.6
# 3.2
# 3.9
# nan
# nan
# 4.0
# 2.3
# 4.2
# nan
# 3.9
# nan
# 4.2
# nan
# 5.2
# nan
# 4.4
# 4.2
# nan
# 4.7
# 3.9
# nan
# nan
# nan
# 4.3
# nan
# 4.4
# nan
# nan
# nan
# nan
# nan
# nan
# 3.6
# nan
# 4.5
# 4.3
# 2.9
# nan
# 2.7
# nan
# 2.7
# 8.0
# 3.8
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 4.1
# 3.3
# nan
# 3.0
# nan
# nan
# nan
# nan
# nan
# 2.9
# 3
# nan
# nan
# 3.9
# nan
# 4.3
# 2.4
# 4.8
# 	?
# 3.2
# 5.4
# nan
# nan
# nan
# ...

# %%
data.isnull().sum()
# Out:
# age                 0
# bp                  0
# sg                  0
# al                  0
# su                  0
# rbc               152
# pc                 65
# pcc                 4
# ba                  4
# bgr                44
# bu                  0
# sc                  0
# sod                87
# pot                88
# hemo                0
# pcv                70
# wc                105
# rc                130
# htn                 2
# dm                  2
# cad                 2
# appet               1
# pe                  1
# ane                 1
# classification      0
# dtype: int64

# %%
data['rc'].value_counts()
# Out:
# rc
# 5.2    18
# 4.5    16
# 4.9    14
# 4.7    11
# 4.8    10
# 3.9    10
# 4.6     9
# 3.4     9
# 5.9     8
# 5.5     8
# 6.1     8
# 5.0     8
# 3.7     8
# 5.3     7
# 5.8     7
# 5.4     7
# 3.8     7
# 5.6     6
# 4.3     6
# 4.2     6
# 3.2     5
# 4.4     5
# 5.7     5
# 6.4     5
# 5.1     5
# 6.2     5
# 6.5     5
# 4.1     5
# 3.6     4
# 6.3     4
# 6.0     4
# 4.0     3
# 3.3     3
# 4       3
# 3.5     3
# 2.9     2
# 3.1     2
# 2.6     2
# 2.1     2
# 2.5     2
# 2.8     2
# 3.0     2
# 2.7     2
# 5       2
# 2.3     1
# \t?     1
# 2.4     1
# 3       1
# 8.0     1
# Name: count, dtype: int64

# %%
data['pcv'].value_counts()
# Out:
# pcv
# 41      21
# 52      21
# 44      19
# 48      19
# 40      16
# 43      14
# 42      13
# 45      13
# 32      12
# 36      12
# 33      12
# 50      12
# 28      12
# 34      11
# 37      11
# 30       9
# 29       9
# 35       9
# 46       9
# 31       8
# 24       7
# 39       7
# 26       6
# 38       5
# 53       4
# 51       4
# 49       4
# 47       4
# 54       4
# 25       3
# 27       3
# 22       3
# 19       2
# 23       2
# 15       1
# 21       1
# 17       1
# 20       1
# \t43     1
# 18       1
# 9        1
# 14       1
# 32       1
# 16       1
# Name: count, dtype: int64

# %%
data.isnull().sum()
# Out:
# age                 0
# bp                  0
# sg                  0
# al                  0
# su                  0
# rbc               152
# pc                 65
# pcc                 4
# ba                  4
# bgr                44
# bu                  0
# sc                  0
# sod                87
# pot                88
# hemo                0
# pcv                70
# wc                105
# rc                130
# htn                 2
# dm                  2
# cad                 2
# appet               1
# pe                  1
# ane                 1
# classification      0
# dtype: int64

# %%
data['rc']
# Out:
# 0      5.2
# 1      NaN
# 2      NaN
# 3      3.9
# 4      4.6
#       ...
# 395    4.9
# 396    6.2
# 397    5.4
# 398    5.9
# 399    6.1
# Name: rc, Length: 400, dtype: object

# %%
data['rc']=data['rc'].fillna(4.8)

# %%
data['rbc']=data['rbc'].fillna(method='bfill')

data['pc']=data['pc'].fillna(method='bfill')
data['pcc']=data['pcc'].fillna(method='bfill')
data['ba']=data['ba'].fillna(method='bfill')
# Out:
# C:\Users\Maitexa user\AppData\Local\Temp\ipykernel_21036\592578219.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data['rbc']=data['rbc'].fillna(method='bfill')
# C:\Users\Maitexa user\AppData\Local\Temp\ipykernel_21036\592578219.py:3: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data['pc']=data['pc'].fillna(method='bfill')
# C:\Users\Maitexa user\AppData\Local\Temp\ipykernel_21036\592578219.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data['pcc']=data['pcc'].fillna(method='bfill')
# C:\Users\Maitexa user\AppData\Local\Temp\ipykernel_21036\592578219.py:5: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
# ...

# %%
data
# Out:
#      age  bp     sg   al   su     rbc        pc         pcc          ba  \
# 0     48  80  1.020  1.0  0.0  normal    normal  notpresent  notpresent
# 1      7  50  1.020  4.0  0.0  normal    normal  notpresent  notpresent
# 2     62  80  1.010  2.0  3.0  normal    normal  notpresent  notpresent
# 3     48  70  1.005  4.0  0.0  normal  abnormal     present  notpresent
# 4     51  80  1.010  2.0  0.0  normal    normal  notpresent  notpresent
# ..   ...  ..    ...  ...  ...     ...       ...         ...         ...
# 395   55  80  1.020  0.0  0.0  normal    normal  notpresent  notpresent
# 396   42  70  1.025  0.0  0.0  normal    normal  notpresent  notpresent
# 397   12  80  1.020  0.0  0.0  normal    normal  notpresent  notpresent
# 398   17  60  1.025  0.0  0.0  normal    normal  notpresent  notpresent
# 399   58  80  1.025  0.0  0.0  normal    normal  notpresent  notpresent
#
#        bgr    bu   sc    sod  pot  hemo pcv    wc   rc  htn   dm cad appet  \
# ...

# %%
data['htn']=data['htn'].fillna(method='ffill')

data['dm']=data['dm'].fillna(method='ffill')

data['cad']=data['cad'].fillna(method='ffill')

data['pe']=data['pe'].fillna(method='ffill')
data['ane']=data['ane'].fillna(method='ffill')
data['appet']=data['appet'].fillna(method='ffill')

data['bgr']=data['bgr'].fillna(method='bfill')
data['sod']=data['sod'].fillna(method='bfill')

data['pot']=data['pot'].fillna(method='bfill')
data
# Out:
# C:\Users\Maitexa user\AppData\Local\Temp\ipykernel_21036\2298168375.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data['htn']=data['htn'].fillna(method='ffill')
# C:\Users\Maitexa user\AppData\Local\Temp\ipykernel_21036\2298168375.py:3: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data['dm']=data['dm'].fillna(method='ffill')
# C:\Users\Maitexa user\AppData\Local\Temp\ipykernel_21036\2298168375.py:5: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data['cad']=data['cad'].fillna(method='ffill')
# C:\Users\Maitexa user\AppData\Local\Temp\ipykernel_21036\2298168375.py:7: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
# ...

# %%
data.isnull().sum()
# Out:
# age                 0
# bp                  0
# sg                  0
# al                  0
# su                  0
# rbc                 0
# pc                  0
# pcc                 0
# ba                  0
# bgr                 0
# bu                  0
# sc                  0
# sod                 0
# pot                 0
# hemo                0
# pcv                70
# wc                105
# rc                  0
# htn                 0
# dm                  0
# cad                 0
# appet               0
# pe                  0
# ane                 0
# classification      0
# dtype: int64

# %%
data['wc'].value_counts()
# Out:
# wc
# 9800     11
# 6700     10
# 9200      9
# 9600      9
# 7200      9
#          ..
# 19100     1
# 6700      1
# 12300     1
# 14900     1
# 12700     1
# Name: count, Length: 92, dtype: int64

# %%
data['pcv']=data['pcv'].fillna(11)

data['wc']=data['wc'].fillna(9600)

# %%
data.head()
# Out:
#    age  bp     sg   al   su     rbc        pc         pcc          ba    bgr  \
# 0   48  80  1.020  1.0  0.0  normal    normal  notpresent  notpresent  121.0
# 1    7  50  1.020  4.0  0.0  normal    normal  notpresent  notpresent  423.0
# 2   62  80  1.010  2.0  3.0  normal    normal  notpresent  notpresent  423.0
# 3   48  70  1.005  4.0  0.0  normal  abnormal     present  notpresent  117.0
# 4   51  80  1.010  2.0  0.0  normal    normal  notpresent  notpresent  106.0
#
#      bu   sc    sod  pot  hemo pcv    wc   rc  htn   dm cad appet   pe  ane  \
# 0  36.0  1.2  111.0  2.5  15.4  44  7800  5.2  yes  yes  no  good   no   no
# 1  18.0  0.8  111.0  2.5  11.3  38  6000  4.8   no   no  no  good   no   no
# 2  53.0  1.8  111.0  2.5   9.6  31  7500  4.8   no  yes  no  poor   no  yes
# 3  56.0  3.8  111.0  2.5  11.2  32  6700  3.9  yes   no  no  poor  yes  yes
# 4  26.0  1.4  142.0  3.2  11.6  35  7300  4.6   no   no  no  good   no   no
#
#   classification
# 0            ckd
# ...

# %%
data['ba'].value_counts()
# Out:
# ba
# 0    378
# 1     22
# Name: count, dtype: int64

# %%
data['classification']=data['classification'].replace({'ckd\t':'ckd'})

# %%
from sklearn.preprocessing  import LabelEncoder
l=LabelEncoder()
data['rbc']=l.fit_transform(data['rbc'])
data['pc']=l.fit_transform(data['pc'])
data['pcc']=l.fit_transform(data['pcc'])
data['ba']=l.fit_transform(data['ba'])
data['htn']=l.fit_transform(data['htn'])
data['dm']=l.fit_transform(data['dm'])
data['cad']=l.fit_transform(data['cad'])
data['appet']=l.fit_transform(data['appet'])
data['pe']=l.fit_transform(data['pe'])
data['ane']=l.fit_transform(data['ane'])
data['classification']=l.fit_transform(data['classification'])

# %%
data['bp'].value_counts()
# Out:
# bp
# 80     116
# 70     112
# 60      71
# 90      53
# 100     25
# 180     13
# 50       5
# 110      3
# 140      1
# 120      1
# Name: count, dtype: int64

# %%
data.head()
# Out:
#    age  bp     sg   al   su  rbc  pc  pcc  ba    bgr    bu   sc    sod  pot  \
# 0   48  80  1.020  1.0  0.0    1   1    0   0  121.0  36.0  1.2  111.0  2.5
# 1    7  50  1.020  4.0  0.0    1   1    0   0  423.0  18.0  0.8  111.0  2.5
# 2   62  80  1.010  2.0  3.0    1   1    0   0  423.0  53.0  1.8  111.0  2.5
# 3   48  70  1.005  4.0  0.0    1   0    1   0  117.0  56.0  3.8  111.0  2.5
# 4   51  80  1.010  2.0  0.0    1   1    0   0  106.0  26.0  1.4  142.0  3.2
#
#    hemo pcv    wc   rc  htn  dm  cad  appet  pe  ane  classification
# 0  15.4  44  7800  5.2    1   4    1      0   0    0               0
# 1  11.3  38  6000  4.8    0   3    1      0   0    0               0
# 2   9.6  31  7500  4.8    0   4    1      1   0    1               0
# 3  11.2  32  6700  3.9    1   3    1      1   1    1               0
# 4  11.6  35  7300  4.6    0   3    1      0   0    0               0

# %%
x=data.drop(['classification'],axis=1)
y=data['classification']

# %%
data
# Out:
#      age  bp     sg   al   su  rbc  pc  pcc  ba    bgr    bu   sc    sod  pot  \
# 0     48  80  1.020  1.0  0.0    1   1    0   0  121.0  36.0  1.2  111.0  2.5
# 1      7  50  1.020  4.0  0.0    1   1    0   0  423.0  18.0  0.8  111.0  2.5
# 2     62  80  1.010  2.0  3.0    1   1    0   0  423.0  53.0  1.8  111.0  2.5
# 3     48  70  1.005  4.0  0.0    1   0    1   0  117.0  56.0  3.8  111.0  2.5
# 4     51  80  1.010  2.0  0.0    1   1    0   0  106.0  26.0  1.4  142.0  3.2
# ..   ...  ..    ...  ...  ...  ...  ..  ...  ..    ...   ...  ...    ...  ...
# 395   55  80  1.020  0.0  0.0    1   1    0   0  140.0  49.0  0.5  150.0  4.9
# 396   42  70  1.025  0.0  0.0    1   1    0   0   75.0  31.0  1.2  141.0  3.5
# 397   12  80  1.020  0.0  0.0    1   1    0   0  100.0  26.0  0.6  137.0  4.4
# 398   17  60  1.025  0.0  0.0    1   1    0   0  114.0  50.0  1.0  135.0  4.9
# 399   58  80  1.025  0.0  0.0    1   1    0   0  131.0  18.0  1.1  141.0  3.5
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 25 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             400 non-null    int32
#  1   bp              400 non-null    int32
#  2   sg              400 non-null    float64
#  3   al              400 non-null    float64
#  4   su              400 non-null    float64
#  5   rbc             400 non-null    int32
#  6   pc              400 non-null    int32
#  7   pcc             400 non-null    int32
#  8   ba              400 non-null    int32
#  9   bgr             400 non-null    float64
#  10  bu              400 non-null    float64
#  11  sc              400 non-null    float64
#  12  sod             400 non-null    float64
#  13  pot             400 non-null    float64
#  14  hemo            400 non-null    float64
#  15  pcv             400 non-null    object
#  16  wc              400 non-null    object
# ...

# %%
for i in data['wc']:
    print(i)
# Out:
# 7800
# 6000
# 7500
# 6700
# 7300
# 7800
# 9600
# 6900
# 9600
# 12100
# 9600
# 4500
# 12200
# 9600
# 11000
# 3800
# 9600
# 9600
# 11400
# 5300
# 9200
# 6200
# 6900
# 9600
# 8300
# 8400
# 10300
# 9600
# 9600
# 9600
# 9600
# 7800
# 9600
# 9600
# 9600
# 9800
# 9600
# 6900
# 9600
# 9800
# 9100
# 9600
# 9200
# 7900
# 9600
# 9600
# 6400
# 8600
# 18900
# 21600
# 11000
# 9600
# 4300
# 8500
# 9800
# 9600
# 11300
# 9600
# 7200
# 9600
# 9600
# 9600
# 7700
# 9600
# 9600
# 9600
# 9600
# 9600
# 9600
# 6900
# 8300
# 14600
# 9600
# 6300
# 6400
# 9600
# 	6200
# 7100
# 9600
# 11800
# 9400
# 5500
# 9600
# 9600
# 3800
# 9600
# 9600
# 5800
# 13200
# 9600
# 9800
# 12500
# 5600
# 7000
# 11900
# 9600
# 9600
# 9100
# 5800
# 10400
# 9600
# 10700
# 7000
# 12700
# 9600
# 6800
# 6500
# 13600
# 10200
# 9600
# 11400
# 9000
# 9600
# 9800
# 10300
# 5600
# 9600
# 9800
# 9600
# 9600
# 9600
# 9600
# 9600
# 14900
# 5500
# 9600
# 8200
# 15200
# 5000
# 9600
# 16300
# 12400
# 13200
# 	8400
# 10200
# 9600
# 9600
# 9200
# ...

# %%
x
# Out:
#      age  bp     sg   al   su  rbc  pc  pcc  ba    bgr    bu   sc    sod  pot  \
# 0     48  80  1.020  1.0  0.0    1   1    0   0  121.0  36.0  1.2  111.0  2.5
# 1      7  50  1.020  4.0  0.0    1   1    0   0  423.0  18.0  0.8  111.0  2.5
# 2     62  80  1.010  2.0  3.0    1   1    0   0  423.0  53.0  1.8  111.0  2.5
# 3     48  70  1.005  4.0  0.0    1   0    1   0  117.0  56.0  3.8  111.0  2.5
# 4     51  80  1.010  2.0  0.0    1   1    0   0  106.0  26.0  1.4  142.0  3.2
# ..   ...  ..    ...  ...  ...  ...  ..  ...  ..    ...   ...  ...    ...  ...
# 395   55  80  1.020  0.0  0.0    1   1    0   0  140.0  49.0  0.5  150.0  4.9
# 396   42  70  1.025  0.0  0.0    1   1    0   0   75.0  31.0  1.2  141.0  3.5
# 397   12  80  1.020  0.0  0.0    1   1    0   0  100.0  26.0  0.6  137.0  4.4
# 398   17  60  1.025  0.0  0.0    1   1    0   0  114.0  50.0  1.0  135.0  4.9
# 399   58  80  1.025  0.0  0.0    1   1    0   0  131.0  18.0  1.1  141.0  3.5
#
# ...

# %%
y
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 395    1
# 396    1
# 397    1
# 398    1
# 399    1
# Name: classification, Length: 400, dtype: int32

# %%
data.head()
# Out:
#    age  bp     sg   al   su  rbc  pc  pcc  ba    bgr    bu   sc    sod  pot  \
# 0   48  80  1.020  1.0  0.0    1   1    0   0  121.0  36.0  1.2  111.0  2.5
# 1    7  50  1.020  4.0  0.0    1   1    0   0  423.0  18.0  0.8  111.0  2.5
# 2   62  80  1.010  2.0  3.0    1   1    0   0  423.0  53.0  1.8  111.0  2.5
# 3   48  70  1.005  4.0  0.0    1   0    1   0  117.0  56.0  3.8  111.0  2.5
# 4   51  80  1.010  2.0  0.0    1   1    0   0  106.0  26.0  1.4  142.0  3.2
#
#    hemo pcv    wc   rc  htn  dm  cad  appet  pe  ane  classification
# 0  15.4  44  7800  5.2    1   4    1      0   0    0               0
# 1  11.3  38  6000  4.8    0   3    1      0   0    0               0
# 2   9.6  31  7500  4.8    0   4    1      1   0    1               0
# 3  11.2  32  6700  3.9    1   3    1      1   1    1               0
# 4  11.6  35  7300  4.6    0   3    1      0   0    0               0

# %%
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.3)

# %%
xtrain.shape,xtest.shape,ytrain.shape,ytest.shape
# Out:
# ((280, 24), (120, 24), (280,), (120,))

# %%
xtrain
# Out:
#      age   bp        sg        al        su  rbc  pc  pcc  ba    bgr     bu  \
# 131    5   50  1.010000  0.000000  0.000000    1   1    0   0  219.0   25.0
# 203   51   90  1.017408  1.016949  0.450142    1   1    0   0  207.0   80.0
# 259   35   80  1.020000  0.000000  0.000000    1   1    0   0  104.0   31.0
# 338   62   80  1.020000  0.000000  0.000000    1   1    0   0  132.0   34.0
# 285   66   70  1.020000  0.000000  0.000000    1   1    0   0   94.0   19.0
# ..   ...  ...       ...       ...       ...  ...  ..  ...  ..    ...    ...
# 291   47   80  1.025000  0.000000  0.000000    1   1    0   0  124.0   44.0
# 42    47  100  1.010000  0.000000  0.000000    0   1    0   0  204.0   29.0
# 195   70   90  1.020000  2.000000  1.000000    0   0    0   1  184.0   98.6
# 62    15   60  1.020000  3.000000  0.000000    0   1    0   0   86.0   15.0
# 56    76   70  1.015000  3.000000  4.000000    1   0    1   0   93.0  164.0
#
# ...

# %%
from sklearn.tree import DecisionTreeClassifier
model=DecisionTreeClassifier()
model.fit(xtrain,ytrain)
# Out:
# DecisionTreeClassifier()

# %%
xtest
# Out:
#      age  bp        sg        al        su  rbc  pc  pcc  ba    bgr     bu  \
# 81    45  90  1.017408  1.016949  0.450142    1   1    0   0  360.0   45.0
# 205   61  70  1.017408  1.016949  0.450142    1   1    0   0  100.0   28.0
# 336   25  60  1.020000  0.000000  0.000000    1   1    0   0  119.0   27.0
# 347   43  60  1.025000  0.000000  0.000000    1   1    0   0  108.0   25.0
# 55    35  80  1.005000  3.000000  0.000000    0   1    0   0   93.0   42.0
# ..   ...  ..       ...       ...       ...  ...  ..  ...  ..    ...    ...
# 223   71  90  1.010000  0.000000  3.000000    0   1    0   0  303.0   30.0
# 178   42  90  1.020000  2.000000  0.000000    0   0    1   0   93.0  153.0
# 70    61  80  1.015000  0.000000  4.000000    1   1    0   0  360.0   19.0
# 326   47  60  1.020000  0.000000  0.000000    1   1    0   0  109.0   25.0
# 79    56  80  1.010000  1.000000  0.000000    1   1    0   0  165.0   55.0
#
# ...

# %%
data.head()
# Out:
#    age  bp     sg   al   su  rbc  pc  pcc  ba    bgr    bu   sc    sod  pot  \
# 0   48  80  1.020  1.0  0.0    1   1    0   0  121.0  36.0  1.2  111.0  2.5
# 1    7  50  1.020  4.0  0.0    1   1    0   0  423.0  18.0  0.8  111.0  2.5
# 2   62  80  1.010  2.0  3.0    1   1    0   0  423.0  53.0  1.8  111.0  2.5
# 3   48  70  1.005  4.0  0.0    1   0    1   0  117.0  56.0  3.8  111.0  2.5
# 4   51  80  1.010  2.0  0.0    1   1    0   0  106.0  26.0  1.4  142.0  3.2
#
#    hemo pcv    wc   rc  htn  dm  cad  appet  pe  ane  classification
# 0  15.4  44  7800  5.2    1   4    1      0   0    0               0
# 1  11.3  38  6000  4.8    0   3    1      0   0    0               0
# 2   9.6  31  7500  4.8    0   4    1      1   0    1               0
# 3  11.2  32  6700  3.9    1   3    1      1   1    1               0
# 4  11.6  35  7300  4.6    0   3    1      0   0    0               0

# %%
model.predict([[48,80,1.020,4,0,1,1,0,0,121,36,1.2,111,2.5,15.4,44,7800,5.2,1,4,1,0,0,0]])
# Out:
# c:\Python310\lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array([0])

# %%
model.predict(xtest)
